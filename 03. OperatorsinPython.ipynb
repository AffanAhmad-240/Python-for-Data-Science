# %% [markdown]
# - Arithmetic operators

# %%
a = 6

# %%
b = 8

# %%
a+b
# Out:
# 14

# %%
a-b
# Out:
# -2

# %%
a / b
# Out:
# 0.75

# %%
a//b # show result in int. Ignore values which are after point
# Out:
# 0

# %%
a%b
# Out:
# 6

# %%
a**b
# Out:
# 1679616

# %% [markdown]
# - Conditional operators

# %%
c = 5
d = 81

# %%
c>d
# Out:
# False

# %%
c>=d
# Out:
# False

# %%
c<=d
# Out:
# True

# %%
c==d
# Out:
# False

# %%
c != d
# Out:
# True

# %% [markdown]
# - Logical opertors

# %%
e = True
f = False

# %%
e and f
# Out:
# False

# %%
e or f
# Out:
# True

# %%
not(e)
# Out:
# False

# %%
not(f)
# Out:
# True

# %% [markdown]
# - Assignment operators

# %%
g = 5

# %%
g -= 3

# %%
g
# Out:
# 2

# %%
h = 7

# %%
h *= 6

# %%
h
# Out:
# 42

# %%
i = 3

# %%
i **=3

# %%
i
# Out:
# 27

# %% [markdown]
# - Membership and identity operators

# %%
list1 = ['A','B', 'C', 'D']

# %%
'A' in list1
# Out:
# True

# %%
'A' not in list1
# Out:
# False

# %%
'A' == 'B'
# Out:
# False

# %%
'A' != 'B'
# Out:
# True

# %% [markdown]
# - Bitwise operator

# %%
a= 5

# %%
b = 6

# %%
a & b
# Out:
# 4

# %%
a | b
# Out:
# 7
