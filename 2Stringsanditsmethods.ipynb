# %%
name = "My World"

# %%
print("Hey,", name)
# Out:
# Hey, My World

# %%
name.upper()
# Out:
# 'MY WORLD'

# %%
name.lower()
# Out:
# 'my world'

# %%
name.startswith("A")
# Out:
# False

# %%
name.endswith("d")
# Out:
# True

# %%
name.replace("World", "LifeH")
# Out:
# 'My LifeH'

# %%
len(name)
# Out:
# 8

# %%
name.count("W")
# Out:
# 1

# %%
names = "Ahmad,Danish,Subook"

# %%
names.split(",")     # convert string into list
# Out:
# ['Ahmad', 'Danish', 'Subook']

# %%
list = ['Mangoes' , 'Apples' , 'Bananas']

# %%
"  ".join(list)     # convert list into string
# Out:
# 'Mangoes  Apples  Bananas'

# %%
name.find("y")     # return the first occurance of that word
# Out:
# 1

# %%
line = "In this video, we learnt string methods"

# %%
len(line)   #it include spaces and , as well
# Out:
# 39

# %%
line[0:38]       # From this point, below all are example of slicing . It print from start to n-1 . For this case: e.g:5-1 = 4
# Out:
# 'In this video, we learnt string method'

# %%
line[:21]        # 21-1 = 20 , actually it print chracter from 0 index to 20th index
# Out:
# 'In this video, we lea'

# %%
line[5:]
# Out:
# 'is video, we learnt string methods'

# %%
line[7:-2]
# Out:
# ' video, we learnt string metho'

# %%
line[7:37]
# Out:
# ' video, we learnt string metho'

# %%
line[-14:-1]
# Out:
# 'string method'

# %%
line[-14+39:-1+39]
# Out:
# 'string method'
