# %%
x = input("What's the value of x")
# Out:
# What's the value of x 34

# %%
y = input("What's the value of y")
# Out:
# What's the value of y 23

# %%
x
# Out:
# '34'

# %%
y
# Out:
# '23'

# %%
type(x)
# Out:
# str

# %%
type(y)
# Out:
# str

# %%
x+y  # when we take input from the user, be dafault its data type is str. 
# therefore when we run this cell, it concatenate both x and y values
# Out:
# '3423'

# %%
int(x) + int(y)
# Out:
# 57

# %%
m = float(input())
# Out:
#  2.5

# %%
n = float(input())
# Out:
#  1.4

# %%
m+n
# Out:
# 3.9
