# %% [markdown]
# # Tuple
# - Tuple is an ordered, immutable collecion of elements. It is similar to list but once its created ,its elemnent cannot be changed.

# %%
t1 = ()

# %%
type(t1)
# Out:
# tuple

# %%
t2 = (1,)      #if you write single element, then comma is reuqired after the element. Otherwise python considered 
              #it as int data type

# %%
t2
# Out:
# (1,)

# %%
type(t2)
# Out:
# tuple

# %%
t3 = (2,5,7,9)

# %%
t3
# Out:
# (2, 5, 7, 9)

# %%
t4 = ('Apple' , True, 23 , 56.8)

# %%
t4
# Out:
# ('Apple', True, 23, 56.8)

# %%
t4[1]
# Out:
# True

# %%
type(t4[3]) # we can check the type of each element in list or tuple
# Out:
# float

# %%
len(t4)
# Out:
# 4

# %% [markdown]
# # Tuple Methods

# %%
t5 = (1, 3, 5, 7)

# %%
t6 = (9, 11, 13, 15)

# %%
t5 + t6
# Out:
# (1, 3, 5, 7, 9, 11, 13, 15)

# %%
t5
# Out:
# (1, 3, 5, 7)

# %%
t6
# Out:
# (9, 11, 13, 15)

# %%
t5.index(3)
# Out:
# 1

# %%
newt = (2,4,9,7,2,5,8,9)

# %%
newt.index(9, 3,8)        #tuple.index(value, startindex,endindex)
# Out:
# 7

# %%
newt.count(7)
# Out:
# 1

# %%
t7 = (9, 5, 90, 12)

# %%
sorted(t7)          # return new tuple but original remain same
# Out:
# [5, 9, 12, 90]

# %%
t7
# Out:
# (9, 5, 90, 12)

# %%
min(t7)
# Out:
# 5

# %%
max(t7)
# Out:
# 90

# %%
sum(t6)
# Out:
# 48

# %%
5 in t7
# Out:
# True

# %%
for _ in t7:
    print(_)
# Out:
# 9
# 5
# 90
# 12

# %%
t8 = (4, 'T', 8.9, True)

# %%
list(t8)       #returns new list and original tuple remain same
# Out:
# [4, 'T', 8.9, True]

# %%
t8
# Out:
# (4, 'T', 8.9, True)

# %%
str(t8)
# Out:
# "(4, 'T', 8.9, True)"

# %%
# Packing tuple
tx = ('Ahmad' , 'Analyst' , 21)

# %%
# unpacking tuple
name, profession, age = tx

# %%
name
# Out:
# 'Ahmad'

# %%
profession
# Out:
# 'Analyst'

# %%
age
# Out:
# 21

# %%
# Nested tuple
ty = (2, 3, 5, (6 , (7.2 , 8.2), 9.1), 10)

# %%
ty
# Out:
# (2, 3, 5, (6, (7.2, 8.2), 9.1), 10)

# %%
ty[3][1][1]
# Out:
# 8.2

# %%
ty[3][0]
# Out:
# 6
