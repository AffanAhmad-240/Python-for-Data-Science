# %%
print("Hey everyone")
# Out:
# Hey everyone

# %%
a = 21

# %%
b = 3.4

# %%
a+b
# Out:
# 24.4

# %%
type(a)
# Out:
# int

# %%
print(type(b))
# Out:
# <class 'float'>

# %%
c = "Affan"

# %%
type(c)
# Out:
# str

# %%
a = int("9")  # Type casting

# %%
type(a)
# Out:
# int

# %%
b = "2"

# %%
a + int(b)     # Type casting
# Out:
# 11

# %%
""" This is the
basics of
python"""
# Out:
# ' This is the\nbasics of\npython'
