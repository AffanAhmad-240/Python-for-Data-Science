# %% [markdown]
# # List
# - List is an ordered, mutable (changeable) collection of elements. It can contain elements of different datatypes.

# %%
L1 = [24, 'Apple' , 56.1 , True]

# %%
L1
# Out:
# [24, 'Apple', 56.1, True]

# %%
L1[0]
# Out:
# 24

# %%
L1[3] = False

# %%
L1
# Out:
# [24, 'Apple', 56.1, False]

# %%
L2 = [23, 56, 78, 90]

# %%
L2
# Out:
# [23, 56, 78, 90]

# %% [markdown]
# # List Methods

# %%
L2.append(56)

# %%
L2
# Out:
# [23, 56, 78, 90, 56]

# %%
L2.append('ABC')

# %%
L2
# Out:
# [23, 56, 78, 90, 56, 'ABC']

# %%
L2.extend(L1)  # changes occur in original string of L2

# %%
L2
# Out:
# [23, 56, 78, 90, 56, 'ABC', 24, 'Apple', 56.1, False]

# %%
L1.insert(1, 'Mangoes')

# %%
L1
# Out:
# [24, 'Mangoes', 'Apple', 56.1, False]

# %%
L2.remove(56)      #remove the first occurance of 56

# %%
L2
# Out:
# [23, 78, 90, 56, 'ABC', 24, 'Apple', 56.1, False]

# %%
removedEle = L2.pop(2)    # take index and remove element present at that index and returns the removed element

# %%
removedEle
# Out:
# 90

# %%
L1.index('Apple')
# Out:
# 2

# %%
L2.count('ABC')
# Out:
# 1

# %%
L1.reverse()

# %%
L1
# Out:
# [False, 56.1, 'Apple', 'Mangoes', 24]

# %%
L3 = [2,1,5,8,7]

# %%
L3.sort()

# %%
L3
# Out:
# [1, 2, 5, 7, 8]

# %%
L3.reverse()

# %%
L3
# Out:
# [8, 7, 5, 2, 1]

# %%
L4 = [ 23,12,5,98,102]

# %%
sorted(L4)        # return new sorted list and original list remain same
# Out:
# [5, 12, 23, 98, 102]

# %%
L4
# Out:
# [23, 12, 5, 98, 102]

# %%
L5 = ['A' , 'B', 1, 5, 9]

# %%
L5.clear()

# %%
L5
# Out:
# []

# %%
L6 = L4.copy()

# %%
L6
# Out:
# [23, 12, 5, 98, 102]

# %%
# Nested list

# %%
Lx = [2, 5, 1, 9, ['A' , 4, [True , 'B', 5]]]

# %%
Lx
# Out:
# [2, 5, 1, 9, ['A', 4, [True, 'B', 5]]]

# %%
Lx[0]
# Out:
# 2

# %%
Lx[4]
# Out:
# ['A', 4, [True, 'B', 5]]

# %%
Lx[4][0]
# Out:
# 'A'

# %%
Lx[4][2]
# Out:
# [True, 'B', 5]

# %%
Lx[4][2][1]
# Out:
# 'B'

# %%
# List concatenation

# %%
L4 + L1
# Out:
# [23, 12, 5, 98, 102, False, 56.1, 'Apple', 'Mangoes', 24]

# %%
L4
# Out:
# [23, 12, 5, 98, 102]

# %%
L1
# Out:
# [False, 56.1, 'Apple', 'Mangoes', 24]

# %%
str1 = "AffanANDTahaANDBilalANDAbdullah"

# %%
str1.split("AND")
# Out:
# ['Affan', 'Taha', 'Bilal', 'Abdullah']

# %%
# split string into list of elements.

# %%
len(L4)
# Out:
# 5

# %%
23 in L4
# Out:
# True
